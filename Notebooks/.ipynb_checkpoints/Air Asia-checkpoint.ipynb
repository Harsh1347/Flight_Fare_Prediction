# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import datetime
from datetime import timedelta
from datetime import datetime
import tensorflow as tf
# %matplotlib inline
# %config IPCompleter.greedy=True
#flight = pd.read_csv("D:\\DataSets\\Rawflight.csv")
data = pd.read_csv("data\\airasia_clean.csv")
del(data['Unnamed:0'])

# %%
flight.airline.value_counts()
# Out:
# Air India        1059925
# IndiGo            611452
# Vistara           547082
# GoAir             353048
# Spicejet          301102
# AirAsia India      99704
# AirAsia              689
# Name: airline, dtype: int64

# %%
def rel(data):
    corel = data.corr().index
    plt.figure(figsize = (10,10))
    corell=sns.heatmap(data[corel].corr(),annot = True,cmap = 'RdYlGn')

# %%
mins =[]
for t in flight.duration:
    m = (int(t.split()[0].split('h')[0])*60) + (int(t.split()[1].split('m')[0]))
    mins.append(m)
flight.replace(["BOM","HYD","NAG","PNQ"],[1,2,3,4],inplace = True)
flight.replace("AirAsia India","AirAsia",inplace = True)
flight['Duration'] = mins
flight['Departure_Date'] = pd.to_datetime(flight.Departure_Date,dayfirst =True)
flight['Search_Date'] = pd.to_datetime(flight.Search_Date,dayfirst =True)
flight['Day_Name'] = flight.Departure_Date.dt.weekday
flight['Dept_Month'] = flight.Departure_Date.dt.month
flight['Search_Month'] = flight.Search_Date.dt.month
flight['Diff_Month'] = flight.Departure_Date.dt.month - flight.Search_Date.dt.month
flight.drop_duplicates(inplace = True)
flight.drop('Unnamed: 0',axis = 1,inplace =True)
tofday = []
for i in flight['deptime']:
    j=int(i.split(':')[0])
    if(j >=0 and j<6):
        tofday.append(1)
    elif(j >=6 and j<12):
        tofday.append(2)
    elif(j>=12 and j< 18):
        tofday.append(3)
    else:
        tofday.append(4)
flight['deptime'] = tofday
tofday1 = []
for i in flight['arrtime']:
    j=int(i.split(':')[0])
    if(j >=0 and j<6):
        tofday1.append(1)
    elif(j >=6 and j<12):
        tofday1.append(2)
    elif(j>=12 and j< 18):
        tofday1.append(3)
    else:
        tofday1.append(4)
flight['arrtime'] = tofday1
data = flight.loc[flight['airline'] == 'AirAsia']
data.reset_index(drop = True,inplace = True)
data.head()
# Out:
#   Search_Date Departure_Date  Days_fly origin  destination  deptime  arrtime  \
# 0  2019-08-07     2019-08-07         0    DEL            1        1        2
# 1  2019-08-07     2019-08-08         1    DEL            1        1        2
# 2  2019-08-07     2019-08-09         2    DEL            1        1        2
# 3  2019-08-07     2019-08-10         3    DEL            1        1        2
# 4  2019-08-07     2019-08-11         4    DEL            1        1        2
#
#    flightno  airline  Total_fare  ...  seatingclass duration stops  stop1  \
# 0       314  AirAsia        2907  ...             E   2h 20m     0    NaN
# 1       314  AirAsia        2907  ...             E   2h 20m     0    NaN
# 2       314  AirAsia        3285  ...             E   2h 20m     0    NaN
# 3       314  AirAsia        3285  ...             E   2h 20m     0    NaN
# 4       314  AirAsia        2907  ...             E   2h 20m     0    NaN
#
#   stop2 Duration  Day_Name  Dept_Month  Search_Month  Diff_Month
# 0   NaN      140         2           8             8           0
# 1   NaN      140         3           8             8           0
# 2   NaN      140         4           8             8           0
# 3   NaN      140         5           8             8           0
# 4   NaN      140         6           8             8           0
#
# [5 rows x 21 columns]

# %%
data.drop(columns = {"origin","seatingclass","stop1","stop2","flightno","airline","seats_avail","duration"},axis = 1,inplace = True)
data['Search_Day'] = data.Search_Date.dt.day
fare_cat = []
for i in data['Total_fare']:
    
    if(i<=3000):
        fare_cat.append(0)
    elif(i>3000 and i<=4000):
        fare_cat.append(1)
    elif(i>4000 and i< 5000):
        fare_cat.append(2)
    elif(i>5000 and i<=6000):
        fare_cat.append(3)
    elif(i>6000 and i<=7000):
        fare_cat.append(4)
    elif(i>7000 and i <= 8000):
        fare_cat.append(5)
    else:
        fare_cat.append(6)
data['Fare_Cat'] = fare_cat
data['Diff_Month'] = [x if x>=0 else x+12 for x in data['Diff_Month']]
data.tail()
data.to_csv("AirAsia_clean.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.shape
data.head()
# Out:
#   Search_Date Departure_Date  Days_fly  destination  deptime  arrtime  \
# 0  2019-08-07     2019-08-07         0            1        1        2
# 1  2019-08-07     2019-08-08         1            1        1        2
# 2  2019-08-07     2019-08-09         2            1        1        2
# 3  2019-08-07     2019-08-10         3            1        1        2
# 4  2019-08-07     2019-08-11         4            1        1        2
#
#    Total_fare  stops  Duration  Day_Name  Dept_Month  Search_Month  \
# 0        2907      0       140         2           8             8
# 1        2907      0       140         3           8             8
# 2        3285      0       140         4           8             8
# 3        3285      0       140         5           8             8
# 4        2907      0       140         6           8             8
#
#    Diff_Month  Search_Day  Fare_Cat
# 0           0           7         0
# 1           0           7         0
# 2           0           7         1
# 3           0           7         1
# 4           0           7         0

# %%
plt.style.use("seaborn")
plt.figure(figsize = (15,7))
data.groupby("Days_fly")["Total_fare"].mean().plot(kind='bar')

# %%
plt.style.use("seaborn")
plt.figure(figsize = (15,7))
data.groupby("Day_Name")["Total_fare"].mean().plot(kind='bar')

# %%
from sklearn.model_selection import train_test_split
data.columns
X = data[['Days_fly','destination','deptime','stops','Day_Name','Diff_Month','Search_Day']]
Y = data['Fare_Cat']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
#import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(7,)),
    tf.keras.layers.Dense(200,activation = 'relu'),
    tf.keras.layers.Dense(150,activation = 'relu'),
    tf.keras.layers.Dense(100,activation = 'relu'),
    tf.keras.layers.Dense(50,activation = 'relu'),
    tf.keras.layers.Dense(25,activation = 'relu'),
    tf.keras.layers.Dense(7,activation = 'softmax'),
    
])

model.compile(optimizer = tf.keras.optimizers.Adam(),loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])
model.fit(X_train,y_train,epochs =200)
# Out:
# Epoch 1/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.2718 - accuracy: 0.4714
# Epoch 2/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.2094 - accuracy: 0.4884
# Epoch 3/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.1717 - accuracy: 0.4982
# Epoch 4/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.1458 - accuracy: 0.5036
# Epoch 5/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.1246 - accuracy: 0.5106
# Epoch 6/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.1098 - accuracy: 0.5162
# Epoch 7/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.0943 - accuracy: 0.5224
# Epoch 8/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 1.0794 - accuracy: 0.5269
# Epoch 9/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.0653 - accuracy: 0.5345
# Epoch 10/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 1.0501 - accuracy: 0.5417
# Epoch 11/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.0345 - accuracy: 0.5493
# Epoch 12/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.0196 - accuracy: 0.5546
# Epoch 13/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 1.0045 - accuracy: 0.5636
# Epoch 14/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9923 - accuracy: 0.5682
# Epoch 15/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9806 - accuracy: 0.5716
# Epoch 16/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9651 - accuracy: 0.5777
# Epoch 17/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9528 - accuracy: 0.5828
# Epoch 18/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9411 - accuracy: 0.5900
# Epoch 19/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9264 - accuracy: 0.5954
# Epoch 20/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9164 - accuracy: 0.6004
# Epoch 21/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.9060 - accuracy: 0.6065
# Epoch 22/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.8932 - accuracy: 0.6093
# Epoch 23/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8828 - accuracy: 0.6161
# Epoch 24/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8717 - accuracy: 0.6216
# Epoch 25/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8615 - accuracy: 0.6281
# Epoch 26/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8513 - accuracy: 0.6330
# Epoch 27/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8419 - accuracy: 0.6377
# Epoch 28/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8327 - accuracy: 0.6417
# Epoch 29/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8244 - accuracy: 0.6446
# Epoch 30/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8168 - accuracy: 0.6487
# Epoch 31/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8088 - accuracy: 0.6517
# Epoch 32/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.8014 - accuracy: 0.6584
# Epoch 33/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7914 - accuracy: 0.6610
# Epoch 34/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7850 - accuracy: 0.6644
# Epoch 35/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7779 - accuracy: 0.6679
# Epoch 36/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7689 - accuracy: 0.6731
# Epoch 37/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7618 - accuracy: 0.6746
# Epoch 38/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7520 - accuracy: 0.6808
# Epoch 39/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.7499 - accuracy: 0.6822
# Epoch 40/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7397 - accuracy: 0.6868
# Epoch 41/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7348 - accuracy: 0.6882
# Epoch 42/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7285 - accuracy: 0.6926
# Epoch 43/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7199 - accuracy: 0.6952
# Epoch 44/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7199 - accuracy: 0.6962
# Epoch 45/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.7098 - accuracy: 0.7015
# Epoch 46/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.7029 - accuracy: 0.7054
# Epoch 47/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6993 - accuracy: 0.7065
# Epoch 48/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6929 - accuracy: 0.7064
# Epoch 49/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6882 - accuracy: 0.7094
# Epoch 50/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6824 - accuracy: 0.7128
# Epoch 51/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6811 - accuracy: 0.7134
# Epoch 52/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6770 - accuracy: 0.7158
# Epoch 53/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6698 - accuracy: 0.7191
# Epoch 54/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6651 - accuracy: 0.7212
# Epoch 55/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6609 - accuracy: 0.7239
# Epoch 56/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6594 - accuracy: 0.7241
# Epoch 57/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6537 - accuracy: 0.7261
# Epoch 58/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6512 - accuracy: 0.7262
# Epoch 59/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6488 - accuracy: 0.7294
# Epoch 60/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6409 - accuracy: 0.7316
# Epoch 61/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6416 - accuracy: 0.7318
# Epoch 62/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6377 - accuracy: 0.7315
# Epoch 63/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.6313 - accuracy: 0.7355
# Epoch 64/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.6311 - accuracy: 0.7355
# Epoch 65/200
# 2507/2507 [==============================] - 6s 2ms/step - loss: 0.6255 - accuracy: 0.7387
# Epoch 66/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.6231 - accuracy: 0.7404
# Epoch 67/200
# 2507/2507 [==============================] - 7s 3ms/step - loss: 0.6191 - accuracy: 0.7426
# Epoch 68/200
# 2507/2507 [==============================] - 7s 3ms/step - loss: 0.6188 - accuracy: 0.7423
# Epoch 69/200
# 2507/2507 [==============================] - 6s 2ms/step - loss: 0.6142 - accuracy: 0.7428
# Epoch 70/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6101 - accuracy: 0.7434
# Epoch 71/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6083 - accuracy: 0.7455
# Epoch 72/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.6036 - accuracy: 0.7481
# Epoch 73/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5997 - accuracy: 0.7489
# Epoch 74/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.6001 - accuracy: 0.7497
# Epoch 75/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5968 - accuracy: 0.7530
# Epoch 76/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5927 - accuracy: 0.7551
# Epoch 77/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5905 - accuracy: 0.7545
# Epoch 78/200
# 2507/2507 [==============================] - 7s 3ms/step - loss: 0.5939 - accuracy: 0.7509
# Epoch 79/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5841 - accuracy: 0.7566
# Epoch 80/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5876 - accuracy: 0.7553
# Epoch 81/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5826 - accuracy: 0.7578
# Epoch 82/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5805 - accuracy: 0.7591
# Epoch 83/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5764 - accuracy: 0.7583
# Epoch 84/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5743 - accuracy: 0.7594
# Epoch 85/200
# 2507/2507 [==============================] - 6s 2ms/step - loss: 0.5713 - accuracy: 0.7612
# Epoch 86/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5702 - accuracy: 0.7624
# Epoch 87/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5682 - accuracy: 0.7627
# Epoch 88/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5654 - accuracy: 0.7654
# Epoch 89/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5629 - accuracy: 0.7662
# Epoch 90/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5601 - accuracy: 0.7650
# Epoch 91/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5592 - accuracy: 0.7655
# Epoch 92/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5571 - accuracy: 0.7660
# Epoch 93/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5573 - accuracy: 0.7696
# Epoch 94/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5525 - accuracy: 0.7695
# Epoch 95/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5499 - accuracy: 0.7701
# Epoch 96/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5490 - accuracy: 0.7727
# Epoch 97/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5471 - accuracy: 0.7725
# Epoch 98/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5432 - accuracy: 0.7751
# Epoch 99/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5427 - accuracy: 0.7755
# Epoch 100/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5409 - accuracy: 0.7755
# Epoch 101/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5411 - accuracy: 0.7751
# Epoch 102/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.5380 - accuracy: 0.7756
# Epoch 103/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5369 - accuracy: 0.7761
# Epoch 104/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5360 - accuracy: 0.7766
# Epoch 105/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5349 - accuracy: 0.7776
# Epoch 106/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5299 - accuracy: 0.7784
# Epoch 107/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5292 - accuracy: 0.7793
# Epoch 108/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5280 - accuracy: 0.7803
# Epoch 109/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5268 - accuracy: 0.7811
# Epoch 110/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5265 - accuracy: 0.7821
# Epoch 111/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5230 - accuracy: 0.7813
# Epoch 112/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5232 - accuracy: 0.7837
# Epoch 113/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5211 - accuracy: 0.7819
# Epoch 114/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5210 - accuracy: 0.7824
# Epoch 115/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5187 - accuracy: 0.7835
# Epoch 116/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5167 - accuracy: 0.7833
# Epoch 117/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5144 - accuracy: 0.7865
# Epoch 118/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5126 - accuracy: 0.7858
# Epoch 119/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5118 - accuracy: 0.7859
# Epoch 120/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5105 - accuracy: 0.7869
# Epoch 121/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5095 - accuracy: 0.7884
# Epoch 122/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5093 - accuracy: 0.7872
# Epoch 123/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5084 - accuracy: 0.7872
# Epoch 124/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5048 - accuracy: 0.7887
# Epoch 125/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5076 - accuracy: 0.7884
# Epoch 126/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5060 - accuracy: 0.7882
# Epoch 127/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5008 - accuracy: 0.7925
# Epoch 128/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5020 - accuracy: 0.7909
# Epoch 129/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5002 - accuracy: 0.7917
# Epoch 130/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.5011 - accuracy: 0.7912
# Epoch 131/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4979 - accuracy: 0.7936
# Epoch 132/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4994 - accuracy: 0.7902
# Epoch 133/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4970 - accuracy: 0.7934
# Epoch 134/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4959 - accuracy: 0.7928
# Epoch 135/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4976 - accuracy: 0.7927
# Epoch 136/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4946 - accuracy: 0.7937
# Epoch 137/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4923 - accuracy: 0.7949
# Epoch 138/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4908 - accuracy: 0.7948
# Epoch 139/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4893 - accuracy: 0.7961
# Epoch 140/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4916 - accuracy: 0.7943
# Epoch 141/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4887 - accuracy: 0.7970
# Epoch 142/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.4878 - accuracy: 0.7956
# Epoch 143/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4855 - accuracy: 0.7961
# Epoch 144/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4830 - accuracy: 0.7989
# Epoch 145/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4850 - accuracy: 0.7974
# Epoch 146/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4816 - accuracy: 0.7982
# Epoch 147/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4815 - accuracy: 0.7996
# Epoch 148/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4811 - accuracy: 0.7994
# Epoch 149/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4799 - accuracy: 0.7991
# Epoch 150/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4801 - accuracy: 0.7977
# Epoch 151/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4776 - accuracy: 0.8014
# Epoch 152/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4762 - accuracy: 0.8010
# Epoch 153/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4765 - accuracy: 0.8001
# Epoch 154/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4760 - accuracy: 0.7994
# Epoch 155/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4747 - accuracy: 0.8025
# Epoch 156/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4713 - accuracy: 0.8024
# Epoch 157/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4724 - accuracy: 0.8021
# Epoch 158/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4726 - accuracy: 0.8029
# Epoch 159/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.4729 - accuracy: 0.8016
# Epoch 160/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4691 - accuracy: 0.8044
# Epoch 161/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4693 - accuracy: 0.8043
# Epoch 162/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4682 - accuracy: 0.8048
# Epoch 163/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4674 - accuracy: 0.8041
# Epoch 164/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4669 - accuracy: 0.8040
# Epoch 165/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4660 - accuracy: 0.8046
# Epoch 166/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4654 - accuracy: 0.8059
# Epoch 167/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4644 - accuracy: 0.8044
# Epoch 168/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4626 - accuracy: 0.8070
# Epoch 169/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4648 - accuracy: 0.8050
# Epoch 170/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4604 - accuracy: 0.8072
# Epoch 171/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4614 - accuracy: 0.8076
# Epoch 172/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4618 - accuracy: 0.8055
# Epoch 173/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.4605 - accuracy: 0.8061
# Epoch 174/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.4608 - accuracy: 0.8051
# Epoch 175/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4575 - accuracy: 0.8087
# Epoch 176/200
# 2507/2507 [==============================] - 5s 2ms/step - loss: 0.4586 - accuracy: 0.8084
# Epoch 177/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4582 - accuracy: 0.8095
# Epoch 178/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4564 - accuracy: 0.8101
# Epoch 179/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4542 - accuracy: 0.8108
# Epoch 180/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4556 - accuracy: 0.8083
# Epoch 181/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4549 - accuracy: 0.8108
# Epoch 182/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4523 - accuracy: 0.8098
# Epoch 183/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4520 - accuracy: 0.8114
# Epoch 184/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4512 - accuracy: 0.8109
# Epoch 185/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4513 - accuracy: 0.8105
# Epoch 186/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4515 - accuracy: 0.8110
# Epoch 187/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4475 - accuracy: 0.8126
# Epoch 188/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4521 - accuracy: 0.8122
# Epoch 189/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4497 - accuracy: 0.8116
# Epoch 190/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4478 - accuracy: 0.8122
# Epoch 191/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4464 - accuracy: 0.8120
# Epoch 192/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4470 - accuracy: 0.8121
# Epoch 193/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4464 - accuracy: 0.8129
# Epoch 194/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4472 - accuracy: 0.8117
# Epoch 195/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4436 - accuracy: 0.8136
# Epoch 196/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4445 - accuracy: 0.8144
# Epoch 197/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4457 - accuracy: 0.8137
# Epoch 198/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4446 - accuracy: 0.8136
# Epoch 199/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4490 - accuracy: 0.8128
# Epoch 200/200
# 2507/2507 [==============================] - 4s 2ms/step - loss: 0.4427 - accuracy: 0.8155

# %%
model.evaluate(X_test,y_test)
# Out:
# 627/627 [==============================] - 1s 1ms/step - loss: 0.6822 - accuracy: 0.7443
# [0.6822162866592407, 0.7443403005599976]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 20)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
from sklearn import metrics
metrics.accuracy_score(pred,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
DT = DecisionTreeClassifier()
RFC = RandomForestClassifier()
DT.fit(X_train,y_train)
RFC.fit(X_train,y_train)

# %%
metrics.accuracy_score(RFC.predict(X_test),y_test)

# %%
import sklearn.metrics as skm

# %%
cm = skm.confusion_matrix(RFC.predict(X_test),pred)
print(cm)

# %%
from sklearn import preprocessing
X_train = preprocessing.scale(X_train)
X_test = preprocessing.scale(X_test)
X_train
# Out:
# array([[ 1.80469529, -0.32590999,  0.32051727, ...,  0.49070745,
#          1.69819111,  1.61090969],
#        [ 1.54436588,  1.29473983, -1.58585461, ...,  0.99127498,
#          1.69819111,  0.21370014],
#        [ 1.54436588,  1.29473983, -1.58585461, ..., -0.00986008,
#          1.69819111, -0.13560224],
#        ...,
#        [ 0.46585828, -0.32590999,  0.32051727, ...,  1.4918425 ,
#          0.65995679,  0.4465684 ],
#        [-1.2448779 ,  1.29473983, -1.58585461, ...,  0.99127498,
#         -0.37827754,  1.84377795],
#        [ 1.80469529,  1.29473983,  0.32051727, ...,  1.4918425 ,
#          1.69819111,  1.61090969]])
